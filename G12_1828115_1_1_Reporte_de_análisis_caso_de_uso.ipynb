# %% [markdown]
# ##FACPYA
# ##LTI
# ##Maestro: Jose Felipe Ramirez Ramirez
# ##Grupo:12
# #Nombre:Marlon Cristo Ruiz Vazquez
# #Matricula:1828115
# #Fecha:22 de octubre del 2023

# %% [markdown]
# PROGRAMA DE CASO
#
# La Comisión Federal de Electricidad tiene un sistema de tarificación que funciona de la siguiente manera:
#
#     1.Se tiene un Límite de Nivel de Tarifa (LNT), que generalmente anda alrededor de los 35 kilowatts por bimestre, pero se tiene que confirmar en cada emisión de recibos.
#     2.Cada bimestre, se realiza una lectura física a los medidores de cada casa, para registrar el consumo por bimestre de cada hogar.
#     3.Todo el consumo igual o menor a LNT, se considera consumo estándar.
#     4.Todo el consumo mayor que LNT se considera consumo alto volumen.
#     5.La tarifa por kilowatt de consumo estándar $45 pesos por kilowatt.
#     6.La tarifa por kilowatt para el consumo alto volumen es de $143 pesos por kilowatt.
#     7.Para el consumo estándar, el gobierno tiene un porcentaje de subsidio del 60%.
#     8.Para el consumo alto volumen, el gobierno tiene un porcentaje de subsidio del 25%.
#     9.El costo por consumo estándar es igual a multiplicar el consumo estándar por la tarifa por kilowatt de consumo estándar.
#     10.El costo por consumo alto volumen es igual a multiplicar el consumo alto volumen por la tarifa por kilowatt de consumo alto volumen.
#     11.El pago del gobierno es igual a sumar la multiplicación del costo de consumo estándar por el subsidio de consumo estándar, más la multiplicación del costo por consumo alto volumen por el subsidio alto volumen.
#     12.El pago del cliente es igual a sumar la multiplicación del costo de consumo estándar por 1 menos el subsidio de consumo estándar, más la multiplicación del costo por consumo alto volumen por 1 menos el subsidio alto volumen.
#     13.Tanto la tarifa por kilowatt de consumo estándar ($45.00), la tarifa por kilowatt de consumo alto volumen ($143.00), el porcentaje de subsidio estándar (0.60), y el porcentaje de subsidio alto volumen (0.25) están definidas por la Ley de Energía, por lo cual son datos que se tienen.
#     14.Elaborar un programa que pregunte el consumo bimestral, en Kilowatts, así como el número de Kilowatts que represente el Límite de Nivel de Tarifa (LNT) del periodo. Deberá calcular cuánto pagará el gobierno por subsidios, y cuánto pagará el cliente.

# %% [markdown]
# | Dato  | Datatype | Origen | Variable | Formula |
# |-------|----------|------|----------|---------|
# |LNT    | Int    |Se Pregunta |LNT|
# |Consumo Bimestral| Int| Se Pregunta|consumo
# Tarifa Estandar| Float| Se tiene| tar_est|=45.00
# Subsidio Estandar|Float|Se tiene| sub_est|=0.60
# Tarifa Alto Volumen|Float|Se tiene| tar_alt|=143.00
# Subsidio Alto|Float|Se tiene|sub_alt|=0.25
# Costo Estandar|Float|Se calcula|costo_est|=consumoxtar_est
# Costo Alto Volumen|Float| Se calcula| costo_alt|=(consumo-LNT)xtar_alt
# Pago Gobierno|Float|Se calcula| pago_gobierno|=(costo_estxsub_est)+(costo_altxsub_alt)
# Pago Cliente|Float|Se Calcula| pago_cliente|=(costo_estx(1-sub_est))+(costo_altx(1-sub_alt))

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
consumo=float(input("Dame el consumo en Kilowatts del bimestre:"))
LNT=float(input("Dame la cantidad de Kilowatts que representa el Límite de Nivel de Tarifa:"))
tar_est=45.00
tar_alt=143.00
sub_est=0.60
sub_alt=0.25
costo_est=consumo*tar_est
costo_alt=(consumo-LNT)*tar_alt
pago_gobierno=(costo_est*sub_est)+(costo_alt*sub_alt)
pago_cliente=(costo_est*(1-sub_est))+(costo_alt*(1-sub_alt))
print("El gobierno paga:",pago_gobierno)
print("El cliente paga:",pago_cliente)
# Out:
# Dame el consumo en Kilowatts del bimestre:45
# Dame la cantidad de Kilowatts que representa el Límite de Nivel de Tarifa:35
# El gobierno paga: 1572.5
# El cliente paga: 1882.5

# %% [markdown]
# Mi experencia al elaborar este codigo fue al principio trate de encontrar la formula para calcular lo que pagaria el gobierno y el cliente, usando el primer ejemplo como guia para saber que resultado me tenia que salir con los datos que se tienen (tarifa estandar y alta y subsidio estandar y alto), despues de tener lo que creia era la formula probe con los datos de ese primer ejemplo y no me daba el mismo resultado, asi que estuve un buen rato viendo que estaba mal, hasta que decidi mejor probar con el segundo ejemplo y si me dio el mismo resultado, ya de ahi solo tuve que poner esas formulas (que tenia en un borrador en bloc de notas) en el codigo despues de preguntar el consumo de Kw y el LNT y declarar las variables.

# %% [markdown]
# https://colab.research.google.com/drive/1I2ggaEPqnerOTtPHC06xeXL1tORqTNPA#scrollTo=xOiiaRyOvhRO&uniqifier=1
